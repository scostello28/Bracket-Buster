# %%
import pandas as pd
import numpy as np

# %%
games = pd.read_pickle('/Users/sec/galvanize/capstone1/merge_test_2014.pkl')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      82         try:
# ---> 83             return read_wrapper(lambda f: pkl.load(f))
#      84         except Exception:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/pickle.py in read_wrapper(func)
#      65                             compression=inferred_compression,
# ---> 66                             is_text=False)
#      67         try:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     387             # Python 3 and binary mode
# --> 388             f = open(path_or_buf, mode)
#     389         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/sec/galvanize/capstone1/merge_test_2014.pkl'
#
# ...

# %%
games['count'] = games.groupby('ID').cumcount() + 1

# %%
games1 = games[games['count'] == 1]
games2 = games[games['count'] == 2]

# %%
games2.columns
# Out:
# Index(['Date', 'Opp', 'W', 'Ws', 'Wp', 'ppg', 'pApg', 'FGp', '3Pp', 'FTp',
#        'ORBpg', 'RBpg', 'ASTpg', 'STLpg', 'BLKpg', 'TOpg', 'PFpg', 'Tm', 'sos',
#        'matchup', 'ID', 'count'],
#       dtype='object')

# %%
games2_stats = games2.iloc[:, 4:21] 
# games2_id = games2['ID']

# %%
games2_stats.head()
# Out:
#            Wp   ppg  pApg     FGp     3Pp     FTp  ORBpg  RBpg  ASTpg  STLpg  \
# 164  0.772727  78.0  76.6  0.4498  0.3988  0.6890   10.2  32.0   12.6    6.4
# 213  0.444444  69.0  69.6  0.4236  0.3420  0.7722    7.0  35.8   14.4    4.6
# 218  0.346154  66.8  75.6  0.4308  0.3130  0.5952    8.0  30.2   15.4    6.2
# 221  0.419355  67.8  63.6  0.4728  0.3694  0.6518    6.8  33.2   16.6    4.8
# 224  0.857143  77.4  75.6  0.4282  0.3034  0.6702   10.0  32.6   13.6    8.8
#
#      BLKpg  TOpg  PFpg        Tm   sos                    matchup  \
# 164    3.6  11.8  22.6  arkansas  2.95           alabama,arkansas
# 213    1.8  13.2  18.6      army -4.65              american,army
# 218    1.4  15.8  20.8      army -4.65              american,army
# 221    2.2  18.2  16.6      army -4.65              american,army
# 224    4.2  11.0  19.8    auburn  4.02  alabama-birmingham,auburn
#
#                                        ID
# 164           alabama,arkansas,2017-02-01
# ...

# %%
g2cols = games2_stats.columns.tolist()

# %%
OPcols = ['OP{}'.format(col) if col != 'ID' else col for col in g2cols]

# %%
OPcols
# Out:
# ['OPWp',
#  'OPppg',
#  'OPpApg',
#  'OPFGp',
#  'OP3Pp',
#  'OPFTp',
#  'OPORBpg',
#  'OPRBpg',
#  'OPASTpg',
#  'OPSTLpg',
#  'OPBLKpg',
#  'OPTOpg',
#  'OPPFpg',
#  'OPTm',
#  'OPsos',
#  'OPmatchup',
#  'ID']

# %%
games2_stats.columns = OPcols

# %%
games2_stats.head()
# Out:
#          OPWp  OPppg  OPpApg   OPFGp   OP3Pp   OPFTp  OPORBpg  OPRBpg  \
# 164  0.772727   78.0    76.6  0.4498  0.3988  0.6890     10.2    32.0
# 213  0.444444   69.0    69.6  0.4236  0.3420  0.7722      7.0    35.8
# 218  0.346154   66.8    75.6  0.4308  0.3130  0.5952      8.0    30.2
# 221  0.419355   67.8    63.6  0.4728  0.3694  0.6518      6.8    33.2
# 224  0.857143   77.4    75.6  0.4282  0.3034  0.6702     10.0    32.6
#
#      OPASTpg  OPSTLpg  OPBLKpg  OPTOpg  OPPFpg      OPTm  OPsos  \
# 164     12.6      6.4      3.6    11.8    22.6  arkansas   2.95
# 213     14.4      4.6      1.8    13.2    18.6      army  -4.65
# 218     15.4      6.2      1.4    15.8    20.8      army  -4.65
# 221     16.6      4.8      2.2    18.2    16.6      army  -4.65
# 224     13.6      8.8      4.2    11.0    19.8    auburn   4.02
#
#                      OPmatchup                                    ID
# 164           alabama,arkansas           alabama,arkansas,2017-02-01
# ...

# %%
# games2 = pd.concat([games2_stats, games2_id], axis=1)
games2 = games2_stats

# %%
games2.head()
# Out:
#          OPWp  OPppg  OPpApg   OPFGp   OP3Pp   OPFTp  OPORBpg  OPRBpg  \
# 164  0.772727   78.0    76.6  0.4498  0.3988  0.6890     10.2    32.0
# 213  0.444444   69.0    69.6  0.4236  0.3420  0.7722      7.0    35.8
# 218  0.346154   66.8    75.6  0.4308  0.3130  0.5952      8.0    30.2
# 221  0.419355   67.8    63.6  0.4728  0.3694  0.6518      6.8    33.2
# 224  0.857143   77.4    75.6  0.4282  0.3034  0.6702     10.0    32.6
#
#      OPASTpg  OPSTLpg  OPBLKpg  OPTOpg  OPPFpg      OPTm  OPsos  \
# 164     12.6      6.4      3.6    11.8    22.6  arkansas   2.95
# 213     14.4      4.6      1.8    13.2    18.6      army  -4.65
# 218     15.4      6.2      1.4    15.8    20.8      army  -4.65
# 221     16.6      4.8      2.2    18.2    16.6      army  -4.65
# 224     13.6      8.8      4.2    11.0    19.8    auburn   4.02
#
#                      OPmatchup                                    ID
# 164           alabama,arkansas           alabama,arkansas,2017-02-01
# ...

# %%
games1.head()
# Out:
#          Date      Opp  W  Ws        Wp   ppg  pApg     FGp     3Pp     FTp  \
# 0  2017-01-14    lamar  1   8  0.470588  63.0  67.2  0.4366  0.3806  0.5842
# 1  2016-11-22  stetson  1   5  1.000000  90.2  67.0  0.5058  0.4332  0.7274
# 2  2016-11-25    akron  0   5  0.833333  87.6  69.6  0.4864  0.4270  0.7528
# 3  2016-12-07     army  0   6  0.600000  72.4  76.2  0.4492  0.4512  0.7666
# 4  2016-12-10   denver  0   6  0.545455  70.4  74.8  0.4374  0.4482  0.7280
#
#    ...   ASTpg  STLpg  BLKpg  TOpg  PFpg                 Tm   sos  \
# 0  ...    12.8    7.0    3.2  15.2  22.6  abilene-christian -6.86
# 1  ...    19.8    4.2    1.2   8.6  19.2          air-force  1.34
# 2  ...    17.4    4.6    1.4   9.8  20.0          air-force  1.34
# 3  ...    12.8    5.8    2.2  12.2  16.0          air-force  1.34
# 4  ...    13.6    6.0    2.4  12.0  15.2          air-force  1.34
#
#                    matchup                                  ID count
# ...

# %%
games = pd.merge(games1, games2, how='left', on='ID')

# %%
games.head()
# Out:
#          Date      Opp  W  Ws        Wp   ppg  pApg     FGp     3Pp     FTp  \
# 0  2017-01-14    lamar  1   8  0.470588  63.0  67.2  0.4366  0.3806  0.5842
# 1  2016-11-22  stetson  1   5  1.000000  90.2  67.0  0.5058  0.4332  0.7274
# 2  2016-11-25    akron  0   5  0.833333  87.6  69.6  0.4864  0.4270  0.7528
# 3  2016-12-07     army  0   6  0.600000  72.4  76.2  0.4492  0.4512  0.7666
# 4  2016-12-10   denver  0   6  0.545455  70.4  74.8  0.4374  0.4482  0.7280
#
#      ...     OPORBpg  OPRBpg  OPASTpg  OPSTLpg  OPBLKpg  OPTOpg  OPPFpg OPTm  \
# 0    ...         NaN     NaN      NaN      NaN      NaN     NaN     NaN  NaN
# 1    ...         NaN     NaN      NaN      NaN      NaN     NaN     NaN  NaN
# 2    ...         NaN     NaN      NaN      NaN      NaN     NaN     NaN  NaN
# 3    ...         NaN     NaN      NaN      NaN      NaN     NaN     NaN  NaN
# 4    ...         NaN     NaN      NaN      NaN      NaN     NaN     NaN  NaN
#
#    OPsos OPmatchup
# 0    NaN       NaN
# ...

# %%
games = games.drop(['Date', 'Opp', 'count', 'ID', 'matchup', 'OPmatchup'], axis=1)
games = games.dropna()

# %%
games
# Out:
#       W  Ws        Wp   ppg  pApg     FGp     3Pp     FTp  ORBpg  RBpg  ...    \
# 12    1   5  0.833333  76.8  61.6  0.4614  0.3736  0.7474    8.8  32.6  ...
# 13    0   6  0.750000  77.8  65.6  0.4936  0.4072  0.7208    8.8  30.4  ...
# 14    0   7  0.700000  72.0  62.0  0.4784  0.4136  0.6546    9.8  31.6  ...
# 15    1   8  0.727273  78.8  67.0  0.5026  0.4208  0.6568   10.2  34.2  ...
# 16    1   9  0.750000  77.4  74.8  0.4792  0.4138  0.6280    9.0  32.0  ...
# 17    1  15  0.833333  80.2  73.2  0.4980  0.4032  0.6910    8.8  34.0  ...
# 18    1  18  0.857143  81.6  74.2  0.4938  0.4074  0.6724    6.0  31.2  ...
# 19    0  19  0.826087  79.4  78.2  0.4564  0.3564  0.6352    6.4  30.4  ...
# 20    1  22  0.846154  73.8  72.4  0.4406  0.3474  0.6654    7.8  29.8  ...
# 21    1  23  0.793103  75.8  72.0  0.4552  0.4004  0.7590    7.2  29.8  ...
# 22    1  27  0.771429  72.4  66.6  0.4548  0.3464  0.6706    8.4  29.2  ...
# ...

# %%
games.columns
# Out:
# Index(['W', 'Ws', 'Wp', 'ppg', 'pApg', 'FGp', '3Pp', 'FTp', 'ORBpg', 'RBpg',
#        'ASTpg', 'STLpg', 'BLKpg', 'TOpg', 'PFpg', 'Tm', 'sos', 'OPWp', 'OPppg',
#        'OPpApg', 'OPFGp', 'OP3Pp', 'OPFTp', 'OPORBpg', 'OPRBpg', 'OPASTpg',
#        'OPSTLpg', 'OPBLKpg', 'OPTOpg', 'OPPFpg', 'OPTm', 'OPsos'],
#       dtype='object')
