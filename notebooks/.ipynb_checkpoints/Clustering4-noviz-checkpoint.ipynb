# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, silhouette_samples
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
df = pd.read_pickle('../data/player_stats.pkl')

# %%
df.head()
# Out:
#                       Player   G    GS    MP    FG   FGA    FG%    2P   2PA  \
# 0            Julian Edmonson  30   5.0   568  10.5  26.2  0.401   6.2  15.2
# 1            Jacob Lancaster  31  11.0   434  12.0  21.7  0.553  11.8  21.5
# 2               Parker Wentz  31  29.0  1040   7.7  15.7  0.491   3.2   5.6
# 3         LaDarrien Williams  16  14.0   474   8.1  21.8  0.371   6.4  16.3
# 4           Harrison Hawkins  16  16.0   481   6.8  18.1  0.374   3.7  10.4
# 5               James Pegues  31   0.0   445   7.3  16.6  0.440   7.2  15.8
# 6              Rafael Farley  27  11.0   421   6.2  15.6  0.396   1.5   4.9
# 7   Alexsander Milosavljevic  19   0.0   127   7.9  15.4  0.515   7.9  14.9
# 8               Austin Cooke  31  31.0   914   5.2  11.8  0.437   2.1   4.3
# 9              Michael Grant  31  17.0   642   5.1  10.2  0.495   5.1   9.8
# 10               Riley Payne  31  20.0   584   3.9   8.3  0.476   3.9   8.3
# 11            Chris Blakeley  26   1.0   145   0.8   3.7  0.222   0.8   2.0
# 12              Tre' Coggins  27  25.0   958   9.3  22.0  0.424   4.7  10.1
# 13                 Zach Moer  12   0.0    52   8.2  16.5  0.500   8.2  12.9
# 14                   Max Yon  30  30.0  1038   7.4  17.0  0.434   5.2  10.2
# 15           Marek Olesinski  30  28.0   904   7.2  16.8  0.430   4.1   7.4
# 16              Austin Flues   1   0.0     6   0.0   0.0    NaN   0.0   0.0
# 17           Kamryn Williams  23  22.0   718   7.7  17.8  0.431   6.0  12.4
# 18                Zach Kocur  27   1.0   261   5.6  13.1  0.429   2.8   5.4
# 19            Darrius Parker  18   3.0   238   6.2  10.0  0.615   5.7   8.2
#
#       2P%   ...    TOV   PF   PTS   ORtg   DRtg               Team  Season  \
# 0   0.411   ...    5.6  6.6  34.5  102.3  107.9  abilene-christian    2014
# 1   0.551   ...    5.6  6.7  29.1  102.9   99.3  abilene-christian    2014
# 2   0.576   ...    3.4  4.0  24.5  124.7  107.5  abilene-christian    2014
# 3   0.389   ...    4.2  5.2  24.4  101.2  104.1  abilene-christian    2014
# 4   0.353   ...    6.0  5.8  24.1  100.9  108.5  abilene-christian    2014
# 5   0.454   ...    6.1  9.4  20.9   93.2  102.5  abilene-christian    2014
# 6   0.314   ...    2.5  4.6  18.7  106.1  112.1  abilene-christian    2014
# 7   0.531   ...    4.7  8.8  17.7   95.1  107.9  abilene-christian    2014
# 8   0.493   ...    1.9  4.9  15.8  124.4  106.1  abilene-christian    2014
# 9   0.519   ...    4.5  6.5  14.6   96.4  106.1  abilene-christian    2014
# 10  0.476   ...    3.3  8.9  11.1   99.6  108.2  abilene-christian    2014
# 11  0.400   ...    7.7  4.9   1.6   47.1  109.8  abilene-christian    2014
# 12  0.468   ...    4.7  4.3  27.6  102.4  108.2          air-force    2014
# 13  0.636   ...    5.9  9.4  24.7  102.0  103.2          air-force    2014
# 14  0.514   ...    4.3  3.4  22.9  104.1  109.5          air-force    2014
# 15  0.550   ...    3.2  4.9  21.4  107.6  107.1          air-force    2014
# 16    NaN   ...    0.0  0.0  20.4  250.0  117.1          air-force    2014
# 17  0.479   ...    4.3  4.9  19.8   97.5  104.1          air-force    2014
# 18  0.522   ...    4.0  6.1  18.5  105.5  107.6          air-force    2014
# 19  0.688   ...    3.1  6.9  17.7  117.6  107.6          air-force    2014
#
#     Class  Pos  Height
# 0     2.0    G    73.0
# 1     2.0    F    82.0
# 2     1.0    G    69.0
# 3     2.0    G    72.0
# 4     2.0    G    72.0
# 5     1.0    F    78.0
# 6     2.0    G    77.0
# 7     2.0    F    81.0
# 8     1.0    F    79.0
# 9     0.0    G    77.0
# 10    0.0    F    77.0
# 11    0.0    G    72.0
# 12    1.0    G    74.0
# 13    1.0    C    83.0
# 14    2.0    G    76.0
# 15    2.0    F    81.0
# 16    0.0    F    80.0
# 17    2.0    F    77.0
# 18    0.0    G    75.0
# 19    0.0    C    79.0
#
# [20 rows x 30 columns]

# %% [markdown]
# ## Functions

# %%
def guards(df):
    df = df[df['Pos'] == 'G']
    return df

# %%
def forwards(df):
    df = df[df['Pos'] == 'F']
    return df

# %%
def centers(df):
    df = df[df['Pos'] == 'C']
    return df

# %%
def drop_cols(df):
    df = df.drop(['G', 'GS', 'MP'], axis=1)
    return df

# %%
def ID(row):
    row['ID'] = ",".join([row['Team'], str(row['Season'])])
    return row

# %% [markdown]
# ## Roster Counts

# %%
df.Pos.value_counts()
# Out:
# G    13323
# F     8508
# C     1480
# Name: Pos, dtype: int64

# %%
df.dropna().Pos.value_counts()
# Out:
# G    11381
# F     5599
# C      489
# Name: Pos, dtype: int64

# %% [markdown]
# ## Reduced DateFrame

# %%
# Features to Cluster Centers
c_reduced_df_cols = ['Player', 'MP', '2P', '3P', 'TRB', 'AST', 'STL',
                     'BLK', 'TOV', 'PTS', 'Team', 'Season', 'Pos', 'Height']

c_df_r = df[c_reduced_df_cols]

# Features to Cluster Forwards
f_reduced_df_cols = ['Player', 'MP', '2P', '2PA', '3P', '3PA', 'TRB', 'AST', 'STL',
                     'BLK', 'TOV', 'PTS', 'Team', 'Season', 'Pos']

f_df_r = df[f_reduced_df_cols]

# Features to Cluster Guards
g_reduced_df_cols = ['Player', 'MP', '3P', 'AST', 'STL', 'TOV',
                     'PTS', 'TRB', 'Team', 'Season', 'Pos']

g_df_r = df[g_reduced_df_cols]

# %% [markdown]
# ## Deal with NaNs

# %%
# Drop NaNs from reduced DataFrames
c_df_r = centers(c_df_r.dropna())
g_df_r = guards(g_df_r.dropna())
f_df_r = forwards(f_df_r.dropna())

# %% [markdown]
# ## Vectorize dfs

# %%
def cluster_matrix(df):
    player = df['Player'].as_matrix()
    position = df['Pos'].as_matrix()
    X = df.drop(['Player', 'MP', 'Team', 'Season', 'Pos'], axis=1).as_matrix()
    return X, player, position

# %%
X_c, player_c, position_c = cluster_matrix(c_df_r)
X_f, player_f, position_f = cluster_matrix(f_df_r)
X_g, player_g, position_g = cluster_matrix(g_df_r)

# %%
X_c_cols = c_df_r.drop(['Player', 'MP', 'Team', 'Season', 'Pos'], axis=1).columns.tolist()
X_f_cols = f_df_r.drop(['Player', 'MP', 'Team', 'Season', 'Pos'], axis=1).columns.tolist()
X_g_cols = g_df_r.drop(['Player', 'MP', 'Team', 'Season', 'Pos'], axis=1).columns.tolist()

# %% [markdown]
# ## Standardize

# %%
scale = StandardScaler()
X_c = scale.fit_transform(X_c)
X_f = scale.fit_transform(X_f)
X_g = scale.fit_transform(X_g)

# %% [markdown]
# ## Cluster

# %%
Ks = range(2, 10, 1)
km = [KMeans(n_clusters=i) for i in Ks]
sil_score_c = [silhouette_score(X_c, km[i].fit(X_c).labels_) for i in range(len(km))]
sil_score_f = [silhouette_score(X_f, km[i].fit(X_f).labels_) for i in range(len(km))]
sil_score_g = [silhouette_score(X_g, km[i].fit(X_g).labels_) for i in range(len(km))]

# %%
fig = plt.figure(figsize=(15, 7))
plt.plot(Ks, sil_score_c)
plt.plot(Ks, sil_score_f)
plt.plot(Ks, sil_score_g)
plt.legend(['Centers', 'Forwards', 'Guards'], loc='best')
plt.grid(True)
plt.title('Silhouette Score Plot');

# %%
ckmeans = KMeans(n_clusters=3, init='k-means++', n_init=20, max_iter=500, tol=0.0001,
                        precompute_distances='auto', verbose=0, random_state=None,
                        copy_x=True, n_jobs=-1, algorithm='auto')
ckmeans.fit(X_c);

# %%
fkmeans = KMeans(n_clusters=3, init='k-means++', n_init=20, max_iter=500, tol=0.0001,
                        precompute_distances='auto', verbose=0, random_state=None,
                        copy_x=True, n_jobs=-1, algorithm='auto')
fkmeans.fit(X_f);

# %%
gkmeans = KMeans(n_clusters=7, init='k-means++', n_init=20, max_iter=500, tol=0.0001,
                        precompute_distances='auto', verbose=0, random_state=None,
                        copy_x=True, n_jobs=-1, algorithm='auto')
gkmeans.fit(X_g);

# %%
cclusters = ckmeans.labels_
fclusters = fkmeans.labels_
gclusters = gkmeans.labels_

# %%
center_labels_dict = {0: 'All Team Centers', 1: 'B Team Centers', 2: 'Shooting Centers'}
forward_labels_dict = {0: 'Deep Forwards', 1: 'Versatile Forwards', 2: 'Supporting Forwards'}
guard_labels_dict = {0: 'All team Guards', 1: 'Supporting Guards', 2: 'Utility 3 Point Shooter', 3: 'B Team Guard', 4: 'Rebounding Guard', 5: 'Utility Thief', 6: 'Benchwarmers'}

# %% [markdown]
# ## Recompose player df with clusters

# %%
centers_df = c_df_r
centers_df['Cluster'] = cclusters
centers_df['Cluster_names'] = centers_df['Cluster'].map(center_labels_dict)
centers_df.head()
# Out:
#             Player   MP   2P   3P   TRB  AST  STL  BLK  TOV   PTS        Team  \
# 13       Zach Moer   52  8.2  0.0   9.4  5.9  1.2  4.7  5.9  24.7   air-force
# 19  Darrius Parker  238  5.7  0.5   9.8  3.3  1.0  1.5  3.1  17.7   air-force
# 36    Pat Forsythe  595  7.2  0.0  11.6  1.7  1.4  3.4  4.8  17.2       akron
# 37  Isaiah Johnson  414  6.8  0.0  12.7  1.8  1.2  4.0  2.8  17.2       akron
# 49    Justin Banks  408  6.6  0.0  17.7  0.9  1.0  4.4  3.0  17.7  alabama-am
#
#     Season Pos  Height  Cluster     Cluster_names
# 13    2014   C    83.0        1    B Team Centers
# 19    2014   C    79.0        2  Shooting Centers
# 36    2014   C    83.0        1    B Team Centers
# 37    2014   C    82.0        2  Shooting Centers
# 49    2014   C    85.0        1    B Team Centers

# %%
centers_df.groupby('Cluster')['MP', '2P', '3P', 'AST', 'STL', 'TOV', 'PTS', 'TRB', 'BLK'].mean().round()
# Out:
#             MP   2P   3P  AST  STL  TOV   PTS   TRB  BLK
# Cluster
# 0        489.0  5.0  3.0  3.0  1.0  3.0  22.0  11.0  2.0
# 1        547.0  9.0  0.0  2.0  1.0  4.0  24.0  16.0  3.0
# 2        271.0  4.0  0.0  1.0  1.0  4.0  11.0  12.0  3.0

# %%
# centers_df[(centers_df['Cluster'] == 0) & (centers_df['Season'] == 2018)].sort_values(by='MP', axis=0, ascending=False).iloc[0, :]
# Out:
# Player               Thomas Welsh
# MP                           1096
# 2P                              6
# 3P                            2.3
# TRB                          18.3
# AST                           2.3
# STL                           1.1
# BLK                           1.5
# TOV                           1.7
# PTS                          21.3
# Team                         ucla
# Season                       2018
# Pos                             C
# Height                         84
# Cluster                         0
# Cluster_names    All Team Centers
# Name: 23438, dtype: object

# %%
# centers_df[(centers_df['Cluster'] == 1) & (centers_df['Season'] == 2018)].sort_values(by='MP', axis=0, ascending=False).iloc[0, :]
# Out:
# Player             Jock Landale
# MP                         1200
# 2P                         15.6
# 3P                          0.2
# TRB                        19.2
# AST                         3.8
# STL                         0.7
# BLK                         1.9
# TOV                         4.4
# PTS                        39.9
# Team             saint-marys-ca
# Season                     2018
# Pos                           C
# Height                       83
# Cluster                       1
# Cluster_names    B Team Centers
# Name: 22661, dtype: object

# %%
# centers_df[(centers_df['Cluster'] == 2) & (centers_df['Season'] == 2018)].sort_values(by='MP', axis=0, ascending=False).iloc[0, :]
# Out:
# Player                 JD Wallace
# MP                           1054
# 2P                            5.6
# 3P                              0
# TRB                          15.2
# AST                           0.5
# STL                           1.6
# BLK                             2
# TOV                           1.8
# PTS                          13.8
# Team                 prairie-view
# Season                       2018
# Pos                             C
# Height                         81
# Cluster                         2
# Cluster_names    Shooting Centers
# Name: 22426, dtype: object

# %%
forwards_df = f_df_r
forwards_df['Cluster'] = fclusters
forwards_df['Cluster_names'] = forwards_df['Cluster'].map(forward_labels_dict)
forwards_df.head()
# Out:
#                       Player   MP    2P   2PA   3P  3PA   TRB  AST  STL  BLK  \
# 1            Jacob Lancaster  434  11.8  21.5  0.1  0.1  19.6  1.0  1.0  5.0
# 5               James Pegues  445   7.2  15.8  0.1  0.8  13.4  2.1  2.9  0.4
# 7   Alexsander Milosavljevic  127   7.9  14.9  0.0  0.5  15.4  1.4  0.0  1.4
# 8               Austin Cooke  914   2.1   4.3  3.0  7.5  11.4  3.9  1.9  0.3
# 10               Riley Payne  584   3.9   8.3  0.0  0.0   7.9  2.4  1.8  0.3
#
#     TOV   PTS               Team  Season Pos  Cluster        Cluster_names
# 1   5.6  29.1  abilene-christian    2014   F        1   Versatile Forwards
# 5   6.1  20.9  abilene-christian    2014   F        1   Versatile Forwards
# 7   4.7  17.7  abilene-christian    2014   F        1   Versatile Forwards
# 8   1.9  15.8  abilene-christian    2014   F        0        Deep Forwards
# 10  3.3  11.1  abilene-christian    2014   F        2  Supporting Forwards

# %%
forwards_df.groupby('Cluster')['MP', '2P', '2PA', '3P', '3PA', 'AST', 'STL', 'TOV', 'PTS', 'TRB'].mean().round()
# Out:
#             MP   2P   2PA   3P   3PA  AST  STL  TOV   PTS   TRB
# Cluster
# 0        535.0  4.0   8.0  3.0  10.0  3.0  1.0  3.0  20.0  10.0
# 1        592.0  9.0  16.0  0.0   2.0  2.0  2.0  4.0  24.0  15.0
# 2        305.0  4.0   8.0  0.0   1.0  2.0  1.0  3.0  11.0  12.0

# %%
# forwards_df[(forwards_df['Cluster'] == 0) & (forwards_df['Season'] == 2018)].sort_values(by='MP', axis=0, ascending=False).iloc[0, :]
# Out:
# Player           Oshae Brissett
# MP                         1411
# 2P                          4.7
# 2PA                        12.8
# 3P                          2.4
# 3PA                         7.4
# TRB                        14.4
# AST                         1.5
# STL                         1.9
# BLK                         1.3
# TOV                           3
# PTS                        24.3
# Team                   syracuse
# Season                     2018
# Pos                           F
# Cluster                       0
# Cluster_names     Deep Forwards
# Name: 23138, dtype: object

# %%
# forwards_df[(forwards_df['Cluster'] == 1) & (forwards_df['Season'] == 2018)].sort_values(by='MP', axis=0, ascending=False).iloc[0, :]
# Out:
# Player               Justin Johnson
# MP                             1314
# 2P                              8.4
# 2PA                            15.4
# 3P                              2.1
# 3PA                             4.9
# TRB                            15.7
# AST                             2.1
# STL                             1.2
# BLK                             1.2
# TOV                             2.5
# PTS                            26.1
# Team               western-kentucky
# Season                         2018
# Pos                               F
# Cluster                           1
# Cluster_names    Versatile Forwards
# Name: 23700, dtype: object

# %%
# forwards_df[(forwards_df['Cluster'] == 2) & (forwards_df['Season'] == 2018)].sort_values(by='MP', axis=0, ascending=False).iloc[0, :]
# Out:
# Player              Steffon Mitchell
# MP                              1128
# 2P                               2.6
# 2PA                              4.8
# 3P                               1.1
# 3PA                                4
# TRB                             14.2
# AST                              3.6
# STL                              1.9
# BLK                              1.8
# TOV                              1.9
# PTS                               11
# Team                  boston-college
# Season                          2018
# Pos                                F
# Cluster                            2
# Cluster_names    Supporting Forwards
# Name: 19496, dtype: object

# %%
guards_df = g_df_r
guards_df['Cluster'] = gclusters
guards_df['Cluster_names'] = guards_df['Cluster'].map(guard_labels_dict)
guards_df.head()
# Out:
#                Player    MP   3P  AST  STL  TOV   PTS   TRB  \
# 0     Julian Edmonson   568  4.3  3.0  2.3  5.6  34.5   5.7
# 2        Parker Wentz  1040  4.5  4.9  2.8  3.4  24.5   3.9
# 3  LaDarrien Williams   474  1.7  7.7  2.4  4.2  24.4  10.5
# 4    Harrison Hawkins   481  3.1  6.3  2.1  6.0  24.1   5.0
# 6       Rafael Farley   421  4.6  1.7  0.6  2.5  18.7   4.9
#
#                 Team  Season Pos  Cluster    Cluster_names
# 0  abilene-christian    2014   G        3     B Team Guard
# 2  abilene-christian    2014   G        3     B Team Guard
# 3  abilene-christian    2014   G        0  All team Guards
# 4  abilene-christian    2014   G        0  All team Guards
# 6  abilene-christian    2014   G        3     B Team Guard

# %%
guards_df.groupby('Cluster')['MP', '3P', 'AST', 'STL', 'TOV', 'PTS', 'TRB'].mean().round()
# Out:
#             MP    3P  AST   STL   TOV   PTS   TRB
# Cluster
# 0        636.0   2.0  8.0   3.0   5.0  17.0   6.0
# 1         21.0  13.0  3.0   1.0   5.0  49.0   9.0
# 2        396.0   1.0  3.0   2.0   4.0  18.0  15.0
# 3        678.0   4.0  4.0   2.0   3.0  24.0   7.0
# 4        300.0   1.0  3.0   2.0   3.0  11.0   6.0
# 5          3.0   0.0  6.0  33.0   6.0  22.0   8.0
# 6          4.0   0.0  3.0   0.0  46.0   5.0  12.0

# %%
# guards_df[(guards_df['Cluster'] == 0) & (guards_df['Season'] == 2018)].sort_values(by='MP', axis=0, ascending=False).iloc[0, :]
# Out:
# Player           Franklin Howard
# MP                          1422
# 3P                           2.9
# AST                          7.6
# STL                            3
# TOV                          5.5
# PTS                         23.3
# TRB                          5.6
# Team                    syracuse
# Season                      2018
# Pos                            G
# Cluster                        0
# Cluster_names    All team Guards
# Name: 23139, dtype: object

# %%
# guards_df[(guards_df['Cluster'] == 1) & (guards_df['Season'] == 2018)].sort_values(by='MP', axis=0, ascending=False).iloc[0, :]
# Out:
# Player              Marquis Godwin
# MP                              91
# 3P                             9.2
# AST                            0.7
# STL                              0
# TOV                              2
# PTS                             33
# TRB                            9.2
# Team                  old-dominion
# Season                        2018
# Pos                              G
# Cluster                          1
# Cluster_names    Supporting Guards
# Name: 22270, dtype: object

# %%
# guards_df[(guards_df['Cluster'] == 2) & (guards_df['Season'] == 2018)].sort_values(by='MP', axis=0, ascending=False).iloc[0, :]
# Out:
# Player                   Jordan Caroline
# MP                                  1290
# 3P                                   1.6
# AST                                  3.6
# STL                                  1.1
# TOV                                  3.1
# PTS                                 28.8
# TRB                                   14
# Team                              nevada
# Season                              2018
# Pos                                    G
# Cluster                                2
# Cluster_names    Utility 3 Point Shooter
# Name: 21816, dtype: object

# %%
# guards_df[(guards_df['Cluster'] == 3) & (guards_df['Season'] == 2018)].sort_values(by='MP', axis=0, ascending=False).iloc[0, :]
# Out:
# Player            Tyus Battle
# MP                       1443
# 3P                        3.3
# AST                       3.3
# STL                       2.3
# TOV                       3.7
# PTS                      30.7
# TRB                       4.7
# Team                 syracuse
# Season                   2018
# Pos                         G
# Cluster                     3
# Cluster_names    B Team Guard
# Name: 23136, dtype: object

# %%
# guards_df[(guards_df['Cluster'] == 4) & (guards_df['Season'] == 2018)].sort_values(by='MP', axis=0, ascending=False).iloc[0, :]
# Out:
# Player             Jonah Radebaugh
# MP                            1350
# 3P                             2.5
# AST                              2
# STL                            1.6
# TOV                            1.3
# PTS                           12.1
# TRB                            9.1
# Team             northern-colorado
# Season                        2018
# Pos                              G
# Cluster                          4
# Cluster_names     Rebounding Guard
# Name: 22110, dtype: object

# %%
# guards_df[(guards_df['Cluster'] == 5) & (guards_df['Season'] == 2018)].sort_values(by='MP', axis=0, ascending=False).iloc[0, :]
# Out:
# Player                        L.J. Thorpe
# MP                                      6
# 3P                                      0
# AST                                  19.1
# STL                                  38.2
# TOV                                  19.1
# PTS                                  47.8
# TRB                                   9.6
# Team             north-carolina-asheville
# Season                               2018
# Pos                                     G
# Cluster                                 5
# Cluster_names               Utility Thief
# Name: 21932, dtype: object

# %%
# guards_df[(guards_df['Cluster'] == 6) & (guards_df['Season'] == 2018)].sort_values(by='MP', axis=0, ascending=False).iloc[0, :]
# Out:
# Player           Leighton Schrand
# MP                              7
# 3P                              0
# AST                             0
# STL                             0
# TOV                          31.6
# PTS                             0
# TRB                           7.9
# Team                       xavier
# Season                       2018
# Pos                             G
# Cluster                         6
# Cluster_names        Benchwarmers
# Name: 23834, dtype: object

# %% [markdown]
# ## Team df

# %%
c = centers_df[['Player', 'MP', 'Team', 'Season', 'Cluster', 'Pos']]
f = forwards_df[['Player', 'MP', 'Team', 'Season', 'Cluster', 'Pos']]
g = guards_df[['Player', 'MP', 'Team', 'Season', 'Cluster', 'Pos']]
positions = [c, f, g]

# %%
teams = pd.concat(positions)

# %%
teams.head(50)
# Out:
#                  Player    MP                      Team  Season  Cluster Pos
# 13            Zach Moer    52                 air-force    2014        1   C
# 19       Darrius Parker   238                 air-force    2014        2   C
# 36         Pat Forsythe   595                     akron    2014        1   C
# 37       Isaiah Johnson   414                     akron    2014        2   C
# 49         Justin Banks   408                alabama-am    2014        1   C
# 60      Fahro Alihodzic   767        alabama-birmingham    2014        1   C
# 68        Devonte' Neal     5             alabama-state    2014        1   C
# 93        Carl Engstrom   365                   alabama    2014        2   C
# 102            John Puk   982                 albany-ny    2014        2   C
# 115         Corey Young    61              alcorn-state    2014        0   C
# 125      Tony Wroblicky  1055                  american    2014        1   C
# 132         Zach Elcano    91                  american    2014        2   C
# 157    Jordan Bachynski  1020             arizona-state    2014        1   C
# 173    Kaleb Tarczewski  1020                   arizona    2014        1   C
# 183      Andrew Poulter    13      arkansas-little-rock    2014        1   C
# 210       David Tillman     5       arkansas-pine-bluff    2014        2   C
# 228      Moses Kingsley   367                  arkansas    2014        1   C
# 240      Kevin Ferguson   841                      army    2014        1   C
# 249      Kieffer Jordan    92                      army    2014        2   C
# 251         Kyle Weldon     5                      army    2014        2   C
# 261  Asauhn Dixon-Tatum   675                    auburn    2014        2   C
# 263     Benas Griciunas   112                    auburn    2014        2   C
# 266       Matthew Atewe   346                    auburn    2014        2   C
# 269        Chris Horton   918               austin-peay    2014        1   C
# 285         Mading Thok    97                ball-state    2014        1   C
# 298       Isaiah Austin  1065                    baylor    2014        1   C
# 304        Josh Clemons     2                    baylor    2014        2   C
# 306           Chad Lang   119                   belmont    2014        1   C
# 327      Travis Elliott   635           bethune-cookman    2014        2   C
# 368          KC Caudill   162            boston-college    2014        2   C
# 370     Dennis Clifford    33            boston-college    2014        2   C
# 395          Josh Gomez   147       bowling-green-state    2014        2   C
# 407      Jordan Prosser   398                   bradley    2014        2   C
# 410          Nate Wells    49                   bradley    2014        2   C
# 429         Rafael Maia   599                     brown    2014        1   C
# 459        Ben Oberfeld    29                  bucknell    2014        2   C
# 480         Nolan Berry    90                    butler    2014        1   C
# 506           Aly Ahmed   567     cal-state-bakersfield    2014        1   C
# 513         Abdul Ahmed   364     cal-state-bakersfield    2014        0   C
# 516          Zech Smith   154     cal-state-bakersfield    2014        2   C
# 558      Mamadou Ndiaye   714         california-irvine    2014        1   C
# 562           John Ryan   501         california-irvine    2014        1   C
# 581       Alan Williams   872  california-santa-barbara    2014        1   C
# 603       Kameron Rooks   182                california    2014        2   C
# 631       Kevin Bleeker   109                  canisius    2014        0   C
# 634          Sean Young     7          central-arkansas    2014        1   C
# 648       Terry Tidwell    61          central-arkansas    2014        2   C
# 663      Justin McBride   140           central-florida    2014        1   C
# 705         Mike Thorne   759                 charlotte    2014        1   C
# 737    Willie Rosenthal    22             chicago-state    2014        2   C
