# %%
import pandas as pd
import numpy as np

# %%
msuurl = 'https://www.sports-reference.com/cbb/schools/michigan/2018-gamelogs.html#sgl-basic::none'

# %%
'''Read team gamelog'''
df = pd.read_html(msuurl)[0]

# %%
'''remove oppenent columns'''
df = df.iloc[:, 0:23]

# %%
df.head()
# Out:
#   Unnamed: 0_level_0      School Unnamed: 2_level_0          Opponent  \
#                    G        Date                                  Opp
# 0                  1  2017-11-11                NaN     North Florida
# 1                  2  2017-11-13                NaN  Central Michigan
# 2                  3  2017-11-16                NaN     Southern Miss
# 3                  4  2017-11-20                  N               LSU
# 4                  5  2017-11-21                  N         Chaminade
#
#   Unnamed: 4_level_0 Unnamed: 5_level_0 Unnamed: 6_level_0 Unnamed: 7_level_0  \
#                  W/L                 Tm                Opp                 FG
# 0                  W                 86                 66                 33
# 1                  W                 72                 65                 26
# 2                  W                 61                 47                 23
# 3                  L                 75                 77                 27
# 4                  W                102                 64                 37
#
#   Unnamed: 8_level_0 Unnamed: 9_level_0         ...          \
#                  FGA                FG%         ...
# 0                 71               .465         ...
# 1                 59               .441         ...
# 2                 47               .489         ...
# 3                 59               .458         ...
# 4                 57               .649         ...
#
#   Unnamed: 13_level_0 Unnamed: 14_level_0 Unnamed: 15_level_0  \
#                    FT                 FTA                 FT%
# 0                  11                  16                .688
# 1                  10                  12                .833
# 2                   7                   9                .778
# 3                  15                  21                .714
# 4                  13                  18                .722
#
#   Unnamed: 16_level_0 Unnamed: 17_level_0 Unnamed: 18_level_0  \
#                   ORB                 TRB                 AST
# 0                  12                  35                  21
# 1                   6                  25                  14
# 2                   8                  31                  13
# 3                  13                  27                  12
# 4                   6                  32                  22
#
#   Unnamed: 19_level_0 Unnamed: 20_level_0 Unnamed: 21_level_0  \
#                   STL                 BLK                 TOV
# 0                  12                   2                  10
# 1                   5                   3                   4
# 2                   5                   3                   9
# 3                   6                   1                   7
# 4                   9                   6                   8
#
#   Unnamed: 22_level_0
#                    PF
# 0                  12
# 1                  11
# 2                  10
# 3                  20
# 4                  12
#
# [5 rows x 23 columns]

# %%
'''Remove Double column headers'''
dubcols = df.columns.tolist()
cols = [col[1] for col in dubcols]
df.columns = cols

# %%
df.columns
# Out:
# Index(['G', 'Date', ' ', 'Opp', 'W/L', 'Tm', 'Opp', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'TRB', 'AST', 'STL', 'BLK',
#        'TOV', 'PF'],
#       dtype='object')

# %%
'''Rename Columns'''
newcols = ['G', 'Date', 'Blank', 'Opp', 'W', 'Pts', 'PtsA', 'FG', 'FGA', 
           'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'RB', 
           'AST', 'STL', 'BLK', 'TO', 'PF']
df.columns = newcols

# %%
df.tail()
# Out:
#       G        Date Blank            Opp    W  Pts PtsA   FG  FGA   FG% ...   \
# 40   39  2018-03-24     N  Florida State    W   58   54   19   49  .388 ...
# 41   40  2018-03-31     N    Loyola (IL)    W   69   57   25   59  .424 ...
# 42  NaN      School   NaN       Opponent  NaN  NaN  NaN  NaN  NaN   NaN ...
# 43    G        Date   NaN            Opp  W/L   Tm  Opp   FG  FGA   FG% ...
# 44   41  2018-04-02     N      Villanova    L   62   79   24   55  .436 ...
#
#      FT  FTA   FT%  ORB   RB  AST  STL  BLK   TO   PF
# 40   16   24  .667    7   29    8    6    4   10   16
# 41   12   18  .667   10   35    8   10    2   11   11
# 42  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 43   FT  FTA   FT%  ORB  TRB  AST  STL  BLK  TOV   PF
# 44   11   18  .611    5   26    6    6    1   10   20
#
# [5 rows x 23 columns]

# %%
'''Remove divider rows'''
df = df[(df['Date'] != 'School') & (df['Date'] != 'Date')]

# %%
df.tail()
# Out:
#      G        Date Blank            Opp  W Pts PtsA  FG FGA   FG% ...  FT FTA  \
# 38  37  2018-03-17     N        Houston  W  64   63  21  59  .356 ...  14  20
# 39  38  2018-03-22     N      Texas A&M  W  99   72  39  63  .619 ...   7   8
# 40  39  2018-03-24     N  Florida State  W  58   54  19  49  .388 ...  16  24
# 41  40  2018-03-31     N    Loyola (IL)  W  69   57  25  59  .424 ...  12  18
# 44  41  2018-04-02     N      Villanova  L  62   79  24  55  .436 ...  11  18
#
#      FT% ORB  RB AST STL BLK  TO  PF
# 38  .700   7  33  13   4   5   7  22
# 39  .875   2  26  21  12   0   6  15
# 40  .667   7  29   8   6   4  10  16
# 41  .667  10  35   8  10   2  11  11
# 44  .611   5  26   6   6   1  10  20
#
# [5 rows x 23 columns]

# %%
def teams_dict(filepath):
    '''
    Create dictionary of school names and formatted school names for mapping
    '''
    team_names = pd.read_csv(filepath)
    team_names = team_names[['School', 'School_format']]
    team_dict = {}
    schools = team_names['School'].tolist()
    schools_format = team_names['School_format'].tolist()
    for school, schform in zip(schools, schools_format):
        team_dict[school] = schform
    return team_dict

# %%
def school_name_transform(school_name):
    school_name = school_name.lower()
    school_name = school_name.replace(" & ", " ")
    school_name = school_name.replace("&", "")
    school_name = school_name.replace("ncaa", "")
    school_name = school_name.strip()
    school_name = school_name.replace(" ", "-")
    school_name = school_name.replace("(", "")
    school_name = school_name.replace(")", "")
    school_name = school_name.replace(".", "")
    school_name = school_name.replace("'", "")

    if school_name == 'siu-edwardsville':
        school_name = 'southern-illinois-edwardsville'
    elif school_name == 'vmi':
        school_name = 'virginia-military-institute'
    elif school_name == 'uc-davis':
        school_name = 'california-davis'
    elif school_name == 'uc-irvine':
        school_name = 'california-irvine'
    elif school_name == 'uc-riverside':
        school_name = 'california-riverside'
    elif school_name == 'uc-santa-barbara':
        school_name = 'california-santa-barbara'

    return school_name

# %%
'''reformat Opponent team name column strings'''
team_names_sos_filepath = '/Users/sec/galvanize/capstone1/team_list/sos_team_list_2018_final.csv'
# df['Opp'] = df['Opp'].map(teams_dict(team_names_sos_filepath))
df['Opp'] = df['Opp'].apply(school_name_transform)

# %%
'''Only take the first charcter in W field then map to 0's and 1's.
        (Ties and overtime have excess characters)'''
df['W'] = df['W'].astype(str).str[0]
df['W'] = df['W'].map({'W': 1, 'L': 0})

# %%
'''Create win precentage and rolling average Features'''
df['Ws'] = df['W'].cumsum(axis=0)
df['Wp'] = df['Ws'].astype(int) / df['G'].astype(int)
df['ppg'] = df['Pts'].rolling(window=5,center=False).mean()
df['pApg'] = df['PtsA'].rolling(window=5,center=False).mean()
df['FGp'] = df['FG%'].rolling(window=5,center=False).mean()
df['3Pp'] = df['3P%'].rolling(window=5,center=False).mean()
df['FTp'] = df['FT%'].rolling(window=5,center=False).mean()
df['ORBpg'] = df['ORB'].rolling(window=5,center=False).mean()
df['RBpg'] = df['RB'].rolling(window=5,center=False).mean()
df['ASTpg'] = df['AST'].rolling(window=5,center=False).mean()
df['STLpg'] = df['STL'].rolling(window=5,center=False).mean()
df['BLKpg'] = df['BLK'].rolling(window=5,center=False).mean()
df['TOpg'] = df['TO'].rolling(window=5,center=False).mean()
df['PFpg'] = df['PF'].rolling(window=5,center=False).mean()

# %%
df.head()
# Out:
#    G        Date Blank                       Opp  W  Pts PtsA  FG FGA   FG%  \
# 0  1  2016-11-11     N                   arizona  0   63   65  25  58  .431
# 1  2  2016-11-15     N                  kentucky  0   48   69  20  61  .328
# 2  3  2016-11-18   NaN  mississippi-valley-state  1  100   53  39  59  .661
# 3  4  2016-11-20   NaN        florida-gulf-coast  1   78   77  25  49  .510
# 4  5  2016-11-23     N               st-johns-ny  1   73   62  25  58  .431
#
#    ...      FGp     3Pp     FTp ORBpg  RBpg ASTpg STLpg BLKpg  TOpg  PFpg
# 0  ...      NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  ...      NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  ...      NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  ...      NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  ...   0.4722  0.3974  0.5402   9.2  37.2  18.8   2.8   4.2  15.0  19.0
#
# [5 rows x 37 columns]

# %%
'''Remove columns after rolling ave calcs'''
df = df.drop(['G', 'Blank', 'Pts', 'PtsA', 'FG', 'FGA', 'FG%',
              '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'RB', 
              'AST', 'STL', 'BLK', 'TO', 'PF'], axis=1)

# %%
df = df.dropna()

# %%
'''Add Team Column'''
team = 'michigan-state'
df['Tm'] = team

# %%
def sos_dict(filepath):
    '''
    Create dictionary of school names and strength of schedule for mapping
    '''
    team_sos = pd.read_csv(filepath)
    team_sos = team_sos[['School_format', 'SOS']]
    sos_dict = {}
    schools = team_sos['School_format'].tolist()
    sos = team_sos['SOS'].tolist()
    for school, sos in zip(schools, sos):
        sos_dict[school] = sos
    return sos_dict

# %%
def sos_dict_creator(season):
    '''
    Inputs: season

    Output: Ditionary to match team with sos
    '''

    url = 'https://www.sports-reference.com/cbb/seasons/{}-school-stats.html#basic_school_stats::none'.format(season)

    '''Read season school stats'''
    df = pd.read_html(url)[0]

    '''Transform'''

    '''Remove double Headers'''
    dub_header = df.columns.tolist()
    cols = [col[1].lower() for col in dub_header]
    df.columns = cols

    '''Pick needed columns'''
    df = df[['school', 'sos']]

    '''Add season column'''
    df['season'] = season

    '''Update School Names'''
    df['school'] = df['school'].apply(school_name_transform)

    '''Remove divider rows'''
    df = df[df['school'] != 'overall']
    df = df[df['school'] != 'school']
    df.reset_index(inplace=True, level=None)
    df = df.drop(['index'], axis=1)

    '''Transform to dict'''
    sos_dict = {k: float(v)for k, v in zip(df['school'], df['sos'])}

    return sos_dict

# %%
'''Add SOS columns'''
# df['sos'] = df['Tm'].map(sos_dict(team_names_sos_filepath))
df['sos'] = df['Tm'].map(sos_dict_creator(2018))

# %%
df.head()
# Out:
#          Date            Opp  W  Ws        Wp   ppg  pApg     FGp     3Pp  \
# 4  2016-11-23    st-johns-ny  1   3  0.600000  72.4  65.2  0.4722  0.3974
# 5  2016-11-24         baylor  0   3  0.500000  71.4  66.8  0.4722  0.3942
# 6  2016-11-25  wichita-state  1   4  0.571429  77.2  67.4  0.5066  0.4438
# 7  2016-11-29           duke  0   4  0.500000  71.0  72.4  0.4726  0.3922
# 8  2016-12-03   oral-roberts  1   5  0.555556  71.4  72.2  0.4594  0.3564
#
#       FTp  ORBpg  RBpg  ASTpg  STLpg  BLKpg  TOpg  PFpg              Tm  sos
# 4  0.5402    9.2  37.2   18.8    2.8    4.2  15.0  19.0  michigan-state  7.1
# 5  0.5846    7.8  37.0   19.2    2.6    5.2  14.0  17.2  michigan-state  7.1
# 6  0.6514    6.8  35.6   21.4    3.0    5.6  13.0  18.2  michigan-state  7.1
# 7  0.6742    6.0  34.8   18.0    2.4    5.0  13.6  19.2  michigan-state  7.1
# 8  0.7060    7.0  36.2   17.6    2.6    5.0  13.2  19.4  michigan-state  7.1

# %% [markdown]
# Datetime work for tourney v season game labels

# %%
from datetime import date
tourney2017start = date(2017,3,14)
tourney2017end = date(2017,4,3)

# %%
'''datetime to date'''
df['just_date'] = pd.to_datetime(df['Date']).dt.date

# %%
def tourney_game_label(row):
    '''
    Create Column for tourney games
    '''
    
    if row['just_date'] >= tourney2017start and row['just_date'] <= tourney2017end:

        row['game_type'] = 'tourney2017'

    else:
        
        row['game_type'] = 'season'

    return row

# %%
df = df.apply(tourney_game_label, axis=1)

# %%
df
# Out:
#           Date               Opp  W  Ws        Wp   ppg  pApg     FGp     3Pp  \
# 4   2016-11-23       st-johns-ny  1   3  0.600000  72.4  65.2  0.4722  0.3974
# 5   2016-11-24            baylor  0   3  0.500000  71.4  66.8  0.4722  0.3942
# 6   2016-11-25     wichita-state  1   4  0.571429  77.2  67.4  0.5066  0.4438
# 7   2016-11-29              duke  0   4  0.500000  71.0  72.4  0.4726  0.3922
# 8   2016-12-03      oral-roberts  1   5  0.555556  71.4  72.2  0.4594  0.3564
# 9   2016-12-06  youngstown-state  1   6  0.600000  72.2  71.2  0.4746  0.3454
