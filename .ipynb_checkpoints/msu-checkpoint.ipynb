# %%
import pandas as pd
import numpy as np

# %%
msuurl = 'https://www.sports-reference.com/cbb/schools/michigan-state/2018-gamelogs.html#sgl-basic::none'

# %%
df = pd.read_html(msuurl)[0]

# %%
df = df.iloc[:, 0:23]
df = df.drop(df.index[[20,21]])

# %%
# df.columns

# %%
dubcols = df.columns.tolist()

# %%
cols = [col[1] for col in dubcols]

# %%
cols
# Out:
# ['G',
#  'Date',
#  '\xa0',
#  'Opp',
#  'W/L',
#  'Tm',
#  'Opp',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF']

# %%
df.columns = cols

# %%
# df.head()

# %%
# df.columns
# Out:
# Index(['G', 'Date', ' ', 'Opp', 'W/L', 'Tm', 'Opp', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'TRB', 'AST', 'STL', 'BLK',
#        'TOV', 'PF'],
#       dtype='object')

# %%
newcols = ['G', 'Date', 'Blank', 'Opp', 'W', 'Pts', 'PtsA', 'FG', 'FGA', 
           'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'RB', 
           'AST', 'STL', 'BLK', 'TO', 'PF']

# %%
df.columns = newcols

# %%
df['W'] = df['W'].astype(str).str[0]

# %%
df['W'] = df['W'].map({'W': 1, 'L': 0})

# %%
df['Opp'] = df['Opp'].str.lower()
df['Opp'] = df['Opp'].str.replace("[^\w\s\n.']",'')

# %%
df.columns
# Out:
# Index(['G', 'Date', 'Blank', 'Opp', 'W', 'Pts', 'PtsA', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'RB', 'AST', 'STL',
#        'BLK', 'TO', 'PF'],
#       dtype='object')

# %%
df['Ws'] = df['W'].cumsum(axis=0)
df['Wp'] = df['Ws'].astype(int) / df['G'].astype(int)
df['ppg'] = df['Pts'].rolling(window=5,center=False).mean()
df['pApg'] = df['PtsA'].rolling(window=5,center=False).mean()
df['FGp'] = df['FG%'].rolling(window=5,center=False).mean()
df['3Pg'] = df['3P%'].rolling(window=5,center=False).mean()
df['FTp'] = df['FT%'].rolling(window=5,center=False).mean()
df['ORBpg'] = df['ORB'].rolling(window=5,center=False).mean()
df['RBpg'] = df['RB'].rolling(window=5,center=False).mean()
df['ASTpg'] = df['AST'].rolling(window=5,center=False).mean()
df['STLpg'] = df['STL'].rolling(window=5,center=False).mean()
df['BLKpg'] = df['BLK'].rolling(window=5,center=False).mean()
df['TOpg'] = df['TO'].rolling(window=5,center=False).mean()
df['PFpg'] = df['PF'].rolling(window=5,center=False).mean()

# %%
# df.columns

# %%
df = df.drop(['G', 'Blank', 'Pts', 'PtsA', 'FG', 'FGA', 'FG%',
              '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'RB', 
              'AST', 'STL', 'BLK', 'TO', 'PF'], axis=1)

# %%
df = df.dropna()

# %%
df
# Out:
#      G               Opp  W  Ws        Wp    ppg  pApg     FGp     3Pg  \
# 4    5             UConn  1   4  0.800000   84.4  66.6  0.5236  0.3644
# 5    6               UNC  1   5  0.833333   77.4  62.4  0.4888  0.3914
# 6    7        Notre Dame  1   6  0.857143   77.4  57.4  0.4906  0.4052
# 7    8          Nebraska  1   7  0.875000   76.0  54.6  0.4696  0.3912
# 8    9           Rutgers  1   8  0.888889   73.8  54.8  0.4524  0.3804
# 9   10     Southern Utah  1   9  0.900000   76.0  56.0  0.4504  0.3864
# 10  11           Oakland  1  10  0.909091   80.6  61.6  0.4738  0.3876
# 11  12   Houston Baptist  1  11  0.916667   85.8  61.4  0.4990  0.4018
# 12  13  Long Beach State  1  12  0.923077   89.0  62.0  0.5260  0.4388
# 13  14   Cleveland State  1  13  0.928571   98.8  63.8  0.5790  0.4780
# 14  15    Savannah State  1  14  0.933333  102.8  61.6  0.6098  0.4560
# 15  16          Maryland  1  15  0.937500  103.8  59.2  0.6206  0.4920
# 16  17        Ohio State  0  15  0.882353   95.2  62.8  0.5700  0.4480
# 17  18           Rutgers  1  16  0.888889   90.0  65.2  0.5306  0.4532
# 18  19          Michigan  0  16  0.842105   82.2  69.4  0.4918  0.3840
# 19  20           Indiana  1  17  0.850000   77.6  70.4  0.4744  0.4112
# 22  21          Illinois  1  18  0.857143   76.8  73.0  0.4966  0.3858
# 23  22         Wisconsin  1  19  0.863636   79.2  69.2  0.5186  0.4140
# 24  23          Maryland  1  20  0.869565   78.8  68.4  0.5156  0.3668
# 25  24        Penn State  1  21  0.875000   79.6  65.6  0.5242  0.4148
# 26  25           Indiana  1  22  0.880000   75.2  66.2  0.5136  0.4148
# 27  26              Iowa  1  23  0.884615   77.0  70.0  0.4894  0.4202
# 28  27            Purdue  1  24  0.888889   75.4  70.8  0.4860  0.4026
# 29  28         Minnesota  1  25  0.892857   78.0  68.6  0.5132  0.4822
# 30  29      Northwestern  1  26  0.896552   75.8  67.0  0.5002  0.4768
