# %%
import pandas as pd
import numpy as np

# %%
msuurl = 'https://www.sports-reference.com/cbb/schools/michigan-state/2018-gamelogs.html#sgl-basic::none'

# %%
df = pd.read_html(msuurl)[0]

# %%
df = df.iloc[:, 0:23]
df = df.drop(df.index[[20,21]])

# %%
# df.columns

# %%
dubcols = df.columns.tolist()

# %%
cols = [col[1] for col in dubcols]

# %%
cols
# Out:
# ['G',
#  'Date',
#  '\xa0',
#  'Opp',
#  'W/L',
#  'Tm',
#  'Opp',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF']

# %%
df.columns = cols

# %%
df
# Out:
#      G        Date                    Opp       W/L   Tm Opp  FG FGA   FG%  \
# 0    1  2017-11-10  NaN     North Florida         W   98  66  35  61  .574
# 1    2  2017-11-14    N              Duke         L   81  88  31  61  .508
# 2    3  2017-11-19  NaN       Stony Brook         W   93  71  33  57  .579
# 3    4  2017-11-23    N            DePaul         W   73  51  25  53  .472
# 4    5  2017-11-25    N             UConn         W   77  57  32  66  .485
# 5    6  2017-11-26    N               UNC         W   63  45  22  55  .400
# 6    7  2017-11-30  NaN        Notre Dame         W   81  63  31  60  .517
# 7    8  2017-12-03  NaN          Nebraska         W   86  57  27  57  .474
# 8    9  2017-12-05    @           Rutgers         W   62  52  22  57  .386
# 9   10  2017-12-09  NaN     Southern Utah         W   88  63  28  59  .475
# 10  11  2017-12-16    N           Oakland         W   86  73  31  60  .517
# 11  12  2017-12-18  NaN   Houston Baptist         W  107  62  36  56  .643
# 12  13  2017-12-21  NaN  Long Beach State         W  102  60  39  64  .609
# 13  14  2017-12-29  NaN   Cleveland State         W  111  61  41  63  .651
# 14  15  2017-12-31  NaN    Savannah State         W  108  52  44  70  .629
# 15  16  2018-01-04  NaN          Maryland         W   91  61  32  56  .571
# 16  17  2018-01-07    @        Ohio State         L   64  80  23  59  .390
# 17  18  2018-01-10  NaN           Rutgers  W (1 OT)   76  72  21  51  .412
# 18  19  2018-01-13  NaN          Michigan         L   72  82  21  46  .457
# 19  20  2018-01-19  NaN           Indiana         W   85  57  32  59  .542
# 22  21  2018-01-22    @          Illinois         W   87  74  30  44  .682
# 23  22  2018-01-26  NaN         Wisconsin         W   76  61  27  54  .500
# 24  23  2018-01-28    @          Maryland         W   74  68  25  63  .397
# 25  24  2018-01-31  NaN        Penn State         W   76  68  24  48  .500
# 26  25  2018-02-03    @           Indiana         W   63  60  23  47  .489
# 27  26  2018-02-06    @              Iowa         W   96  93  32  57  .561
# 28  27  2018-02-10  NaN            Purdue         W   68  65  29  60  .483
# 29  28  2018-02-13    @         Minnesota         W   87  57  32  60  .533
# 30  29  2018-02-17    @      Northwestern         W   65  60  20  46  .435
# 31  30  2018-02-20  NaN          Illinois         W   81  61  24  51  .471
# 32  31  2018-02-25    @         Wisconsin         W   68  63  23  53  .434
# 33  32  2018-03-02    N         Wisconsin         W   63  60  24  56  .429
# 34  33  2018-03-03    N          Michigan         L   64  75  24  63  .381
#
#    ...  FT FTA   FT% ORB TRB AST STL BLK TOV  PF
# 0  ...  25  32  .781  13  45  22  12  10  21  21
# 1  ...  10  18  .556   8  30  25   1  12  17  21
# 2  ...  22  27  .815  11  40  20   5   7  14  20
# 3  ...  13  17  .765   8  37  17   5   1  14  26
# 4  ...   5  10  .500  11  38  12   3   4   8  16
# 5  ...   9  13  .692  10  44  16   7   7  22  23
# 6  ...  10  14  .714  13  39  21   4   6  13  14
# 7  ...  27  36  .750  11  45  16   1  11   6  16
# 8  ...  10  16  .625  12  40  15   4  13  14  17
# 9  ...  23  31  .742  14  48  24   6  12  11  12
# 10 ...  15  23  .652  14  43  18   7   6  17  16
# 11 ...  25  33  .758  10  42  30   4  16  14  22
# 12 ...  11  13  .846  12  35  28   9  10  11  15
# 13 ...  14  18  .778  15  47  29   1   4  11  18
# 14 ...  12  22  .545  14  57  35   6   7  17  14
# 15 ...  11  15  .733   7  33  30   4   9   7  17
# 16 ...  11  13  .846   9  33  13   3   1  11  17
# 17 ...  25  34  .735   7  36  19   3   8  13  19
# 18 ...  27  32  .844   8  32  13   3   8  17  26
# 19 ...  11  17  .647  11  44  23   2   7  13  14
# 22 ...  23  28  .821   9  37  15   5   9  25  18
# 23 ...  14  16  .875   9  34  19   2   9  12  19
# 24 ...  19  23  .826  16  40  11   6   7   9  19
# 25 ...  20  25  .800   4  38  18   5   7  15  14
# 26 ...   8  17  .471   3  26  15   3  13  11  24
# 27 ...  24  29  .828   6  31  20   3   4  10  19
# 28 ...   4   6  .667   6  37  21   2   4   6  14
# 29 ...   9  14  .643  12  46  27   3   4  13  14
# 30 ...  17  21  .810   6  31  16   3   0  11  16
# 31 ...  22  26  .846   7  40  20   2  11   8  20
# 32 ...  14  18  .778  13  38  10   4   8  12  18
# 33 ...  10  11  .909  11  36  10   3   7  10  14
# 34 ...   9  10  .900   9  32  10   4   1   8  23
#
# [33 rows x 23 columns]

# %%
# df.columns

# %%
newcols = ['G', 'Date', 'Blank', 'Opp', 'W', 'Pts', 'PtsA', 'FG', 'FGA', 
           'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'RB', 
           'AST', 'STL', 'BLK', 'TO', 'PF']

# %%
df.columns = newcols

# %%
df['W'] = df['W'].astype(str).str[0]

# %%
df['W'] = df['W'].map({'W': 1, 'L': 0})

# %%
df['Opp'] = df['Opp'].str.lower()
df['Opp'] = df['Opp'].str.replace("[^\w\s\n.']",'')
df['Opp'] = df['Opp'].str.replace("",'-')

# %%
df.columns
# Out:
# Index(['G', 'Date', 'Blank', 'Opp', 'W', 'Pts', 'PtsA', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'RB', 'AST', 'STL',
#        'BLK', 'TO', 'PF'],
#       dtype='object')

# %%
df['Ws'] = df['W'].cumsum(axis=0)
df['Wp'] = df['Ws'].astype(int) / df['G'].astype(int)
df['ppg'] = df['Pts'].rolling(window=5,center=False).mean()
df['pApg'] = df['PtsA'].rolling(window=5,center=False).mean()
df['FGp'] = df['FG%'].rolling(window=5,center=False).mean()
df['3Pg'] = df['3P%'].rolling(window=5,center=False).mean()
df['FTp'] = df['FT%'].rolling(window=5,center=False).mean()
df['ORBpg'] = df['ORB'].rolling(window=5,center=False).mean()
df['RBpg'] = df['RB'].rolling(window=5,center=False).mean()
df['ASTpg'] = df['AST'].rolling(window=5,center=False).mean()
df['STLpg'] = df['STL'].rolling(window=5,center=False).mean()
df['BLKpg'] = df['BLK'].rolling(window=5,center=False).mean()
df['TOpg'] = df['TO'].rolling(window=5,center=False).mean()
df['PFpg'] = df['PF'].rolling(window=5,center=False).mean()

# %%
# df.columns

# %%
df = df.drop(['G', 'Blank', 'Pts', 'PtsA', 'FG', 'FGA', 'FG%',
              '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'RB', 
              'AST', 'STL', 'BLK', 'TO', 'PF'], axis=1)

# %%
df = df.dropna()

# %%
df
# Out:
#           Date               Opp  W  Ws        Wp    ppg  pApg     FGp  \
# 4   2017-11-25             uconn  1   4  0.800000   84.4  66.6  0.5236
# 5   2017-11-26               unc  1   5  0.833333   77.4  62.4  0.4888
# 6   2017-11-30        notre dame  1   6  0.857143   77.4  57.4  0.4906
# 7   2017-12-03          nebraska  1   7  0.875000   76.0  54.6  0.4696
# 8   2017-12-05           rutgers  1   8  0.888889   73.8  54.8  0.4524
# 9   2017-12-09     southern utah  1   9  0.900000   76.0  56.0  0.4504
# 10  2017-12-16           oakland  1  10  0.909091   80.6  61.6  0.4738
# 11  2017-12-18   houston baptist  1  11  0.916667   85.8  61.4  0.4990
# 12  2017-12-21  long beach state  1  12  0.923077   89.0  62.0  0.5260
# 13  2017-12-29   cleveland state  1  13  0.928571   98.8  63.8  0.5790
# 14  2017-12-31    savannah state  1  14  0.933333  102.8  61.6  0.6098
# 15  2018-01-04          maryland  1  15  0.937500  103.8  59.2  0.6206
# 16  2018-01-07        ohio state  0  15  0.882353   95.2  62.8  0.5700
# 17  2018-01-10           rutgers  1  16  0.888889   90.0  65.2  0.5306
# 18  2018-01-13          michigan  0  16  0.842105   82.2  69.4  0.4918
# 19  2018-01-19           indiana  1  17  0.850000   77.6  70.4  0.4744
# 22  2018-01-22          illinois  1  18  0.857143   76.8  73.0  0.4966
# 23  2018-01-26         wisconsin  1  19  0.863636   79.2  69.2  0.5186
# 24  2018-01-28          maryland  1  20  0.869565   78.8  68.4  0.5156
# 25  2018-01-31        penn state  1  21  0.875000   79.6  65.6  0.5242
# 26  2018-02-03           indiana  1  22  0.880000   75.2  66.2  0.5136
# 27  2018-02-06              iowa  1  23  0.884615   77.0  70.0  0.4894
# 28  2018-02-10            purdue  1  24  0.888889   75.4  70.8  0.4860
# 29  2018-02-13         minnesota  1  25  0.892857   78.0  68.6  0.5132
