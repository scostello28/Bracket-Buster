# %%
import pandas as pd
import numpy as np
# from matchups import Matchup
# %run msu.py

# %%
games.head()
# Out:
#          Date               Opp  W  Ws        Wp   ppg  pApg     FGp     3Pp  \
# 0  2017-11-18    mount-st-marys  0   0  0.000000  73.2  94.2  0.4276  0.4086
# 1  2017-11-19           wofford  0   0  0.000000  76.6  91.8  0.4596  0.4290
# 2  2017-11-21     edward-waters  1   1  0.142857  83.6  90.0  0.4838  0.4266
# 3  2017-11-25          miami-fl  0   1  0.125000  79.6  88.2  0.4786  0.4032
# 4  2017-11-29  eastern-michigan  1   2  0.222222  82.8  82.8  0.4806  0.4398
#
#       FTp  ORBpg  RBpg  ASTpg  STLpg  BLKpg  TOpg  PFpg             Tm
# 0  0.7304    9.0  29.8   13.2    5.0    2.8  17.4  18.0  north-florida
# 1  0.7642    9.4  31.4   14.2    5.0    2.8  16.6  16.2  north-florida
# 2  0.7590    9.6  30.8   15.8    5.6    2.8  14.8  16.2  north-florida
# 3  0.7424    7.8  27.6   13.4    6.2    2.2  15.4  17.2  north-florida
# 4  0.7492    8.4  29.0   15.2    7.2    3.2  14.6  17.0  north-florida

# %%
def get_unique(row):
    row['matchup'] = ",".join(sorted([row['Tm'], row['Opp']]))
    row['ID'] = '{},{}'.format(row['matchup'], row['Date'])
    return row

# %%
games.apply(get_unique, axis=1)
# Out:
#            Date                          Opp  W  Ws        Wp   ppg  pApg  \
# 0    2017-11-18               mount-st-marys  0   0  0.000000  73.2  94.2
# 1    2017-11-19                      wofford  0   0  0.000000  76.6  91.8
# 2    2017-11-21                edward-waters  1   1  0.142857  83.6  90.0
# 3    2017-11-25                     miami-fl  0   1  0.125000  79.6  88.2
# 4    2017-11-29             eastern-michigan  1   2  0.222222  82.8  82.8
# 5    2017-12-02              trinity-baptist  1   3  0.300000  83.6  77.6
# 6    2017-12-11                  florida-a&m  1   4  0.363636  87.2  78.2
# 7    2017-12-13        florida-international  1   5  0.416667  84.4  79.8
# 8    2017-12-16                     missouri  0   5  0.384615  81.6  79.6
# 9    2017-12-19                   ball-state  0   5  0.357143  77.8  79.2
# 10   2017-12-22                          lsu  0   5  0.333333  71.2  88.4
# 11   2017-12-30            mississippi-state  0   5  0.312500  67.2  92.4
# ...

# %%
# games['sortmatch'] = games['matchup'].astype(list)

# %%
# games['matchup'] = '{},{}'.format(games.Date,
#                         ','.join(sorted(list(zip(games.Tm, games.Opp)))))

# %%
# games['matchup'][0]

# %%
# games['sortmatch'][0]

# %%
# games['matchup'] = '_'.join(sorted(list(games['Tm'].astype(str), games['Opp'].astype(str))))

# %%
games.head()
# Out:
#          Date               Opp  W  Ws        Wp   ppg  pApg     FGp     3Pp  \
# 0  2017-11-18    mount-st-marys  0   0  0.000000  73.2  94.2  0.4276  0.4086
# 1  2017-11-19           wofford  0   0  0.000000  76.6  91.8  0.4596  0.4290
# 2  2017-11-21     edward-waters  1   1  0.142857  83.6  90.0  0.4838  0.4266
# 3  2017-11-25          miami-fl  0   1  0.125000  79.6  88.2  0.4786  0.4032
# 4  2017-11-29  eastern-michigan  1   2  0.222222  82.8  82.8  0.4806  0.4398
#
#       FTp  ORBpg  RBpg  ASTpg  STLpg  BLKpg  TOpg  PFpg             Tm
# 0  0.7304    9.0  29.8   13.2    5.0    2.8  17.4  18.0  north-florida
# 1  0.7642    9.4  31.4   14.2    5.0    2.8  16.6  16.2  north-florida
# 2  0.7590    9.6  30.8   15.8    5.6    2.8  14.8  16.2  north-florida
# 3  0.7424    7.8  27.6   13.4    6.2    2.2  15.4  17.2  north-florida
# 4  0.7492    8.4  29.0   15.2    7.2    3.2  14.6  17.0  north-florida
