# %%
import pandas as pd
import numpy as np

# %%
sos = pd.read_csv('sos_team_list_2018.csv')

# %%
def format_schools(row):
    row['School_format'] = row['School'].lower()
    row['School_format'] = row['School_format'].replace("&",'')
    row['School_format'] = row['School_format'].replace(" ", "-")
    row['School_format'] = row['School_format'].replace("--", "-")
    row['School_format'] = row['School_format'].replace("'",'')
    row['School_format'] = row['School_format'].replace(".",'')
    row['School_format'] = row['School_format'].replace("(",'')
    row['School_format'] = row['School_format'].replace(")",'')
    row['School_format'] = row['School_format'].rstrip("-")
    return row

# %%
sos = sos.apply(format_schools, axis=1)

# %%
sos.head()
# Out:
#               School    SOS      School_format
# 0  Abilene-Christian  -6.86  abilene-christian
# 1        Air-Force--   1.34          air-force
# 2           Akron---  -1.55              akron
# 3      Alabama-A&M-- -11.58         alabama-am
# 4         Alabama---   4.47            alabama

# %%
sos.to_csv('sos_team_list_2018_updated.csv')

# %%
team_list
# Out:
# ['north-carolina',
#  'kansas',
#  'alabama',
#  'vanderbilt',
#  'kentucky',
#  'virginia',
#  'providence',
#  'texas-am',
#  'st-johns',
#  'villanova',
#  'tcu',
#  'xavier',
#  'temple',
#  'clemson',
#  'louisville',
#  'ole-miss',
#  'duke',
#  'syracuse',
#  'texas',
#  'butler',
#  'tennessee',
#  'baylor',
#  'seton-hall',
#  'florida',
#  'marquette',
#  'south-carolina',
#  'oklahoma',
#  'wisconsin',
#  'wichita-state',
#  'arkansas',
#  'ohio-state',
#  'connecticut',
#  'pittsburgh',
#  'missouri',
#  'colorado',
#  'stanford',
#  'wake-forest',
#  'west-virginia',
#  'southern-california',
#  'iowa-state',
#  'purdue',
#  'georgia-tech',
#  'georgia',
#  'maryland',
#  'auburn',
#  'notre-dame',
#  'lsu',
#  'ucla',
#  'miami-fla',
#  'arizona',
#  'creighton',
#  'texas-tech',
#  'oklahoma-state',
#  'illinois-state',
#  'michigan',
#  'cincinnati',
#  'washington',
#  'california',
#  'smu',
#  'nevada',
#  'rhode-island',
#  'utah',
#  'washington-state',
#  'nc-state',
#  'ucf',
#  'dayton',
#  'kansas-state',
#  'depaul',
#  'boston-college',
#  'iowa',
#  'northern-iowa',
#  'virginia-tech',
#  'penn-state',
#  'arizona-state',
#  'florida-state',
#  'richmond',
#  'illinois',
#  'indiana',
#  'western-kentucky',
#  'oregon',
#  'oregon-state',
#  'houston',
#  'buffalo',
#  'michigan-state',
#  'rutgers',
#  'mississippi-state',
#  'indiana-state',
#  'st-bonaventure',
#  'middle-tennessee',
#  'tulsa',
#  'davidson',
#  'northwestern',
#  'minnesota',
#  'new-mexico',
#  'tulane',
#  'nebraska',
#  'saint-louis',
#  'wyoming',
#  'uc-irvine',
#  'vcu',
#  'san-diego-state',
#  'northeastern',
#  'georgetown',
#  'monmouth',
#  'william-mary',
#  'san-francisco',
#  'kent-state',
#  'southern-illinois',
#  'la-salle',
#  'evansville',
#  'utah-state',
#  'memphis',
#  'colorado-state',
#  'toledo',
#  'cal-state-bakersfield',
#  'san-jose-state',
#  'saint-josephs',
#  'brigham-young',
#  'missouri-state',
#  'george-washington',
#  'pacific',
#  'north-dakota',
#  'unc-wilmington',
#  'boise-state',
#  'gonzaga',
#  'miami-ohio',
#  'loyola-chicago',
#  'fresno-state',
#  'bradley',
#  'ohio',
#  'umkc',
#  'valparaiso',
#  'chicago-state',
#  'utah-valley',
#  'pepperdine',
#  'southern-miss',
#  'drake',
#  'sacramento-state',
#  'massachusetts',
#  'nebraska-omaha',
#  'long-beach-state',
#  'western-carolina',
#  'portland',
#  'morehead-state',
#  'elon',
#  'stony-brook',
#  'unlv',
#  'oral-roberts',
#  'northern-illinois',
#  'western-michigan',
#  'eastern-michigan',
#  'hofstra',
#  'akron',
#  'rider',
#  'louisiana-tech',
#  'san-diego',
#  'fordham',
#  'air-force',
#  'ball-state',
#  'east-carolina',
#  'iona',
#  'south-dakota-state',
#  'marshall',
#  'george-mason',
#  'saint-marys',
#  'northern-arizona',
#  'troy',
#  'furman',
#  'new-mexico-state',
#  'siena',
#  'drexel',
#  'towson',
#  'james-madison',
#  'tennessee-state',
#  'texas-arlington',
#  'central-michigan',
#  'loyola-marymount',
#  'belmont',
#  'austin-peay',
#  'northern-colorado',
#  'delaware',
#  'wofford',
#  'south-florida',
#  'eastern-washington',
#  'north-dakota-state',
#  'uab',
#  'bowling-green',
#  'savannah-state',
#  'fairfield',
#  'e-tennessee-state',
#  'little-rock',
#  'north-florida',
#  'murray-state',
#  'harvard',
#  'vermont',
#  'santa-clara',
#  'southern-utah',
#  'the-citadel',
#  'college-of-charleston',
#  'coastal-carolina',
#  'mercer',
#  'seattle',
#  'unc-asheville',
#  'uc-davis',
#  'samford',
#  'louisiana',
#  'cal-poly',
#  'nc-greensboro',
#  'old-dominion',
#  'detroit',
#  'cal-state-fullerton',
#  'tennessee-tech',
#  'chattanooga',
#  'charlotte',
#  'gardner-webb',
#  'bucknell',
#  'california-riverside',
#  'texas-el-paso',
#  'rice',
#  'marist',
#  'texas-rio-grande-valley',
#  'louisiana-monroe',
#  'hawaii',
#  'princeton',
#  'eastern-illinois',
#  'eastern-kentucky',
#  'south-dakota',
#  'north-texas',
#  'niagara',
#  'florida-atlantic',
#  'lipscomb',
#  'denver',
#  'portland-state',
#  'yale',
#  'manhattan',
#  'weber-state',
#  'georgia-southern',
#  'cleveland-state',
#  'wright-state',
#  'jacksonville-state',
#  'texas-san-antonio',
#  'robert-morris',
#  'nicholls-state',
#  'maryland-baltimore-county',
#  'siu-edwardsville',
#  'northern-kentucky',
#  'kennesaw-state',
#  'longwood',
#  'radford',
#  'cornell',
#  'youngstown-state',
#  'boston-university',
#  'montana',
#  'texas-state-san-marcos',
#  'canisius',
#  'new-hampshire',
#  'columbia',
#  'arkansas-state',
#  'vmi',
#  'fairleigh-dickinson',
#  'winthrop',
#  'oakland',
#  'maine',
#  'iupui',
#  'ipfw',
#  'appalachian-state',
#  'south-alabama',
#  'western-illinois',
#  'grand-canyon',
#  'sam-houston-state',
#  'bryant-university',
#  'holy-cross',
#  'duquesne',
#  'florida-gulf-coast',
#  'georgia-state',
#  'wagner',
#  'loyola-maryland',
#  'southeast-missouri-state',
#  'wisconsin-milwaukee',
#  'st-francis-pa',
#  'st-peters',
#  'idaho',
#  'liberty',
#  'south-carolina-upstate',
#  'lehigh',
#  'northwestern-state',
#  'hartford',
#  'lafayette',
#  'quinnipiac',
#  'pennsylvania',
#  'presbyterian',
#  'montana-state',
#  'albany',
#  'texas-southern',
#  'new-orleans',
#  'colgate',
#  'new-jersey-tech',
#  'umass-lowell',
#  'florida-international',
#  'northridge',
#  'houston-baptist',
#  'southeastern-louisiana',
#  'illinois-chicago',
#  'st-francis-ny',
#  'ut-martin',
#  'santa-barbara',
#  'green-bay',
#  'jacksonville',
#  'high-point',
#  'incarnate-word',
#  'mcneese-state',
#  'american',
#  'dartmouth',
#  'charleston-southern',
#  'liu-brooklyn',
#  'central-arkansas',
#  'coppin-state',
#  'abilene-christian',
#  'idaho-state',
#  'brown',
#  'navy',
#  'maryland-eastern-shore',
#  'norfolk-state',
#  'binghamton',
#  'lamar',
#  'prairie-view-am',
#  'campbell',
#  'sacred-heart',
#  'stephen-f-austin',
#  'hampton',
#  'south-carolina-state',
#  'central-connecticut-state',
#  'mount-st-marys',
#  'florida-am',
#  'stetson',
#  'army-west-point',
#  'mississippi-valley-state',
#  'texas-am-corpus-christi',
#  'alabama-state',
#  'delaware-state',
#  'howard',
#  'alabama-am',
#  'arkansas-pine-bluff',
#  'jackson-state',
#  'grambling',
#  'north-carolina-at',
#  'alcorn-state',
#  'southern',
#  'morgan-state',
#  'north-carolina-central',
#  'bethune-cookman']
